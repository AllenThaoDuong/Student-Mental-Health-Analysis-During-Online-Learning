# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dữ liệu file CSV Steudent Mental Health Analysis During Online Learning vào trong python:
df = pd.read_csv(r'D:\Do An Cuoi Ky\Student Mental Health Analysis\Student Mental Health Analysis During Online Learning.csv')

# %%
#1. Kiểm tra dữ liệu:
##1.2 Số lượng bản ghi và cột:
print(f'\nSố lượng bản ghi: {len(df)}')
print(f'Số lượng cột: {len(df.columns)}')
##1.3 Danh sách các cột:
print('\n Danh sách các cột:')
print(df.columns.tolist())
# Out:
# Số lượng bản ghi: 1005
# Số lượng cột: 10
#
#  Danh sách các cột:
# ['Name', 'Gender', 'Age', 'Education Level', 'Screen Time (hrs/day)', 'Sleep Duration (hrs)', 'Physical Activity (hrs/week)', 'Stress Level', 'Anxious Before Exams', 'Academic Performance Change']

# %%
##1.4 Thông tin chi tiết vể dữ liệu:
print('\n Kiểu và thông tin dữ liệu:')
print(df.info())
# Out:
#  Kiểu và thông tin dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          1005 non-null   object
#  1   Gender                        1005 non-null   object
#  2   Age                           1005 non-null   int64
#  3   Education Level               1005 non-null   object
#  4   Screen Time (hrs/day)         975 non-null    float64
#  5   Sleep Duration (hrs)          985 non-null    float64
#  6   Physical Activity (hrs/week)  995 non-null    float64
#  7   Stress Level                  1005 non-null   object
#  8   Anxious Before Exams          1005 non-null   object
#  9   Academic Performance Change   1005 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 78.6+ KB
# None

# %%
##1.5 Thông tin 5 dòng đầu tiên:
print('\n 5 dòng đầu tiên của dữ liệu:')
print(df.head())
# Out:
#  5 dòng đầu tiên của dữ liệu:
#      Name  Gender  Age Education Level  Screen Time (hrs/day)  \
# 0   Aarav    Male   15         Class 8                    7.1
# 1   Meera  Female   25             MSc                    3.3
# 2  Ishaan    Male   20           BTech                    9.5
# 3  Aditya    Male   20              BA                   10.8
# 4   Anika  Female   17        Class 11                    2.8
#
#    Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# 0                   8.9                           9.3       Medium
# 1                   1.0                           0.2       Medium
# 2                   5.4                           6.2       Medium
# 3                   5.6                         200.0         High
# 4                   5.4                           3.1       Medium
#
#   Anxious Before Exams Academic Performance Change
# 0                   No                        Same
# 1                   No                        Same
# 2                   No                        Same
# 3                  Yes                        Same
# 4                  Yes                        Same

# %%
##1.6 Thống kê mô tả dữ liệu:
print('\nThống kê mô tả dữ liệu:')
print(df.describe(include='all'))
# Out:
# Thống kê mô tả dữ liệu:
#            Name  Gender          Age Education Level  Screen Time (hrs/day)  \
# count      1005    1005  1005.000000            1005             975.000000
# unique       30       7          NaN              23                    NaN
# top     Shaurya  Female          NaN           MTech                    NaN
# freq         59     475          NaN             145                    NaN
# mean        NaN     NaN    20.531343             NaN               6.977333
# std         NaN     NaN     5.952691             NaN               3.159015
# min         NaN     NaN     5.000000             NaN               2.000000
# 25%         NaN     NaN    17.000000             NaN               4.400000
# 50%         NaN     NaN    20.000000             NaN               6.900000
# 75%         NaN     NaN    23.000000             NaN               9.500000
# max         NaN     NaN   150.000000             NaN              25.000000
#
#         Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# count             985.000000                    995.000000         1005
# unique                   NaN                           NaN            9
# top                      NaN                           NaN       Medium
# freq                     NaN                           NaN          481
# mean                6.503147                      5.572060          NaN
# std                 1.689446                      9.792378          NaN
# min                 1.000000                      0.000000          NaN
# 25%                 5.200000                      2.600000          NaN
# 50%                 6.500000                      5.100000          NaN
# 75%                 7.700000                      7.650000          NaN
# max                20.000000                    200.000000          NaN
#
#        Anxious Before Exams Academic Performance Change
# count                  1005                        1005
# unique                    6                           6
# top                     Yes                        Same
# freq                    509                         397
# mean                    NaN                         NaN
# std                     NaN                         NaN
# min                     NaN                         NaN
# 25%                     NaN                         NaN
# 50%                     NaN                         NaN
# 75%                     NaN                         NaN
# max                     NaN                         NaN

# %%
#1.7 Kiểm tra giá trị thiếu trong dữ liệu:
print('\nKiểm tra giá trị thiếu trong dữ liệu:')
missing_values = pd.DataFrame({
    "Cột": df.columns,
    "Số lượng giá trị thiếu": df.isnull().sum(),
    "Tỷ lệ phần trăm giá trị thiếu": (df.isnull().sum()/len(df))*100
})
print(missing_values)
# Out:
# Kiểm tra giá trị thiếu trong dữ liệu:
#                                                        Cột  \
# Name                                                  Name
# Gender                                              Gender
# Age                                                    Age
# Education Level                            Education Level
# Screen Time (hrs/day)                Screen Time (hrs/day)
# Sleep Duration (hrs)                  Sleep Duration (hrs)
# Physical Activity (hrs/week)  Physical Activity (hrs/week)
# Stress Level                                  Stress Level
# Anxious Before Exams                  Anxious Before Exams
# Academic Performance Change    Academic Performance Change
#
#                               Số lượng giá trị thiếu  \
# Name                                               0
# Gender                                             0
# Age                                                0
# Education Level                                    0
# Screen Time (hrs/day)                             30
# Sleep Duration (hrs)                              20
# Physical Activity (hrs/week)                      10
# Stress Level                                       0
# Anxious Before Exams                               0
# Academic Performance Change                        0
#
#                               Tỷ lệ phần trăm giá trị thiếu
# Name                                               0.000000
# Gender                                             0.000000
# Age                                                0.000000
# Education Level                                    0.000000
# Screen Time (hrs/day)                              2.985075
# Sleep Duration (hrs)                               1.990050
# Physical Activity (hrs/week)                       0.995025
# Stress Level                                       0.000000
# Anxious Before Exams                               0.000000
# Academic Performance Change                        0.000000

# %%
#1.8 Kiểm tra dữ liệu trùng lặp:
print('\nKiểm tra dữ liệu trùng lặp:')
duplicate_count = df.duplicated().sum()
print(f'Số lượng bản ghi trùng lặp: {duplicate_count}')
# hiện thị các bản ghi trùng lặp nếu có
if duplicate_count > 0:
    print(df[df.duplicated()])
# Out:
# Kiểm tra dữ liệu trùng lặp:
# Số lượng bản ghi trùng lặp: 5
#        Name  Gender  Age Education Level  Screen Time (hrs/day)  \
# 1000  Anika  Female   26           MTech                    4.7
# 1001   Diya  Female   24             MSc                    7.7
# 1002    Ira  Female   15         Class 9                    4.9
# 1003    Ira  Female   24           MTech                   10.6
# 1004   Diya  Female   21           MTech                    9.4
#
#       Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# 1000                   6.8                           9.6       Medium
# 1001                   7.0                           3.2          Low
# 1002                   5.2                           1.4       Medium
# 1003                   7.4                           7.7          Low
# 1004                   4.0                           9.0          Low
#
#      Anxious Before Exams Academic Performance Change
# 1000                  Yes                    Declined
# 1001                   No                        Same
# 1002                  Yes                    Improved
# 1003                  Yes                        Same
# 1004                   No                    Improved

# %%
# Xóa các bản ghi trùng lặp
df = df.drop_duplicates()

# %%
# Tạo danh sách các biến định lượng vẽ biểu đồ phân phối
df.columns = df.columns.str.strip() # Đản bảo cột chính xác
num_cols = ["Screen Time (hrs/day)", "Sleep Duration (hrs)","Physical Activity (hrs/week)"]
# Khởi tạo biểu đồ phân phối cho các biến định lượng
plt.figure(figsize=(18, 5))
# Vẽ biểu đồ phân phối cho từng biến định lượng
for i, col in enumerate(num_cols):
    plt.subplot(1,3, i + 1)
    sns.boxplot(x='Stress Level', y=col, data=df)
    plt.title(f'Phân phối của {col} theo mức độ căng thẳng')
    plt.xlabel('Stress Level')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
#2. Kiểm tra giá trị bất thường:
print('\nKiểm tra giá trị bất thường:')

#2.1 Kiểm tra giá trị min và max của cột "Age":
print('\n1. Age - Kiểm tra giá trị bất thường:')
print(f'Min: {df["Age"].min()}, Max: {df["Age"].max()}')
print(f'Các giá trị Age > 30: {len(df[df["Age"] > 30])}')
print(f'Các giá trị Age >= 100: {len(df[df["Age"] >= 100])}')

#2.2 Kiểm tra giá trị bất thường của thời gian nhìn trên màn hình:
print('\n2. Screen Time - kiểm tra giá trị bất thường:')
print(f'Min: {df["Screen Time (hrs/day)"].min()}, Max: {df["Screen Time (hrs/day)"].max()}')
print(f'Các giá trị > 15 giờ/ngày: {len(df[df["Screen Time (hrs/day)"] > 15])}')

#2.3 Kiểm tra giá trị bất thường của thời gian ngủ:
print('\n3. Sleep Time - kiểm tra giá trị bất thường:')
print(f'Min: {df["Sleep Duration (hrs)"].min()}, Max: {df["Sleep Duration (hrs)"].max()}')
print(f'Các giá trị thời gian ngủ < 4 giờ/ngày: {len(df[df["Sleep Duration (hrs)"] < 4])}')
print(f'Các giá trị thời gian ngủ > 12 giờ/ngày: {len(df[df["Sleep Duration (hrs)"] > 12])}')

#2.4 Kiểm tra giá trị bất thường của thời gian hoạt đông thể chất:
print('\n4. Physical Activity Time - kiểm tra giá trị bất thường:')
print(f'Min: {df["Physical Activity (hrs/week)"].min()}, Max: {df["Physical Activity (hrs/week)"].max()}')
print(f'Các giá trị thời gian hoạt động thể chất > 50 giờ/Tuần: {len(df[df["Physical Activity (hrs/week)"] > 50])}')
# Out:
# Kiểm tra giá trị bất thường:
#
# 1. Age - Kiểm tra giá trị bất thường:
# Min: 5, Max: 150
# Các giá trị Age > 30: 2
# Các giá trị Age >= 100: 2
#
# 2. Screen Time - kiểm tra giá trị bất thường:
# Min: 2.0, Max: 25.0
# Các giá trị > 15 giờ/ngày: 5
#
# 3. Sleep Time - kiểm tra giá trị bất thường:
# Min: 1.0, Max: 20.0
# Các giá trị thời gian ngủ < 4 giờ/ngày: 1
# Các giá trị thời gian ngủ > 12 giờ/ngày: 4
#
# 4. Physical Activity Time - kiểm tra giá trị bất thường:
# Min: 0.0, Max: 200.0
# Các giá trị thời gian hoạt động thể chất > 50 giờ/Tuần: 3

# %%
#2.5 Phân phối các biến định lượng:
print('\nPhân phối các biến định lượng:')
categorical_cols = ['Gender','Education Level','Stress Level','Anxious Before Exams','Academic Performance Change']
for col in categorical_cols:
    print(f'\nPhân phối cua cột {col}:')
    print(df[col].value_counts().to_frame())
    print(f'Số lượng giá trị duy nhất: {df[col].nunique()}')
# Out:
# Phân phối các biến định lượng:
#
# Phân phối cua cột Gender:
#         count
# Gender
# Male      470
# Female    470
# Other      50
# male        4
# Femal       3
# female      2
# Mal         1
# Số lượng giá trị duy nhất: 7
#
# Phân phối cua cột Education Level:
#                  count
# Education Level
# MTech              142
# MSc                136
# MA                 129
# Class 11            87
# BSc                 85
# Class 9             84
# Class 10            84
# BTech               83
# BA                  61
# Class 8             49
# Class 12            45
# Class 9              3
#   Class 10           2
# Class 10             1
#   MTech              1
#   Class 11           1
# Class 12             1
#   BTech              1
#   Class 8            1
#   Class 12           1
# MSc                  1
#   BA                 1
#   MSc                1
# Số lượng giá trị duy nhất: 23
#
# Phân phối cua cột Stress Level:
#               count
# Stress Level
# Medium          479
# Low             318
# High            180
# medium            8
# low               7
# MEDIUM            4
# Very High         2
# Neutral           1
# high              1
# Số lượng giá trị duy nhất: 9
#
# Phân phối cua cột Anxious Before Exams:
#                       count
# Anxious Before Exams
# Yes                     506
# No                      482
# YES                       4
# yes                       3
# NO                        3
# no                        2
# Số lượng giá trị duy nhất: 6
#
# Phân phối cua cột Academic Performance Change:
#                              count
# Academic Performance Change
# Same                           395
# Improved                       299
# Declined                       296
# Improvedd                        4
# same                             4
# Declin                           2
# Số lượng giá trị duy nhất: 6

# %%
#3. Kiểm tra giá trị về chất lượng của data:
print('\nKiểm tra giá trị về chất lượng của data:')
#3.1 Kiểm tra Outliers của data:
print('\nKiểm tra Outliers của data:')
print('\Age Outliers (>=100):')
print(df[df['Age']>=100][["Name","Age",'Gender','Education Level']])

print('\nScreen Time Outliers (>15 hrs/day):')
print(df[df['Screen Time (hrs/day)']>15][["Name","Screen Time (hrs/day)",'Age','Gender','Education Level']])

print('\nSleep Duration Outliers (<4 or >12 hrs):')
print(df[(df['Sleep Duration (hrs)']<4) | (df['Sleep Duration (hrs)']>12)][["Name","Sleep Duration (hrs)",'Age','Gender','Education Level']])

print('\nPhysical Activity Outliers (>50 hrs/week):')
print(df[df['Physical Activity (hrs/week)']>50][["Name","Physical Activity (hrs/week)",'Age','Gender','Education Level']])
# Out:
# Kiểm tra giá trị về chất lượng của data:
#
# Kiểm tra Outliers của data:
# \Age Outliers (>=100):
#     Name  Age  Gender Education Level
# 571  Ira  150  Female              MA
# 971  Sam  100   Other        Class 11
#
# Screen Time Outliers (>15 hrs/day):
#        Name  Screen Time (hrs/day)  Age  Gender Education Level
# 675     Sam                   25.0   16   Other         Class 9
# 804     Ira                   24.5   19  Female           BTech
# 864  Ananya                   20.0   22  Female             MSc
# 902    Riya                   24.5   21  Female             MSc
# 999  Vihaan                   25.0   23    Male              MA
#
# Sleep Duration Outliers (<4 or >12 hrs):
#       Name  Sleep Duration (hrs)  Age  Gender Education Level
# 1    Meera                   1.0   25  Female             MSc
# 155  Anika                  18.0   16  Female        Class 10
# 309  Arjun                  20.0   18    Male        Class 11
# 745  Meera                  20.0   22  Female           MTech
# 884  Arjun                  20.0   16    Male        Class 10
#
# Physical Activity Outliers (>50 hrs/week):
#        Name  Physical Activity (hrs/week)  Age  Gender Education Level
# 3    Aditya                         200.0   20    Male              BA
# 152   Arjun                         100.0   26    Male           MTech
# 780     Ira                         200.0   21  Female           MTech
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# <>:5: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3108\490256972.py:5: SyntaxWarning: invalid escape sequence '\A'
#   print('\Age Outliers (>=100):')

# %%
#3.2 Kiểm tra khoảng trắng thừa trong form dữ liệu text:
print('\nKiểm tra khoảng trắng thừa Education Level:')
edu_spaces = df[df['Education Level'].str.contains('^\s+', regex = True, na=False)]
if len(edu_spaces) > 0:
    print(df['Education Level'].unique()[:15])
# Out:
# Kiểm tra khoảng trắng thừa Education Level:
# ['Class 8' 'MSc' 'BTech' 'BA' 'Class 11' 'MTech' 'Class 9' 'Class 10' 'MA'
#  'BSc' 'Class 12' '  Class 10' 'Class 10  ' '  MTech' 'Class 9  ']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3108\1150056891.py:3: SyntaxWarning: invalid escape sequence '\s'
#   edu_spaces = df[df['Education Level'].str.contains('^\s+', regex = True, na=False)]

# %%
#3.3 Xử lý giá trị không nhất quán trong định tính:
print('\nXử lý giá trị không nhất quán trong định tính:')
print('\nGender variations:')
print(df['Gender'].value_counts())

print('\nStress Level variations:')
print(df['Stress Level'].value_counts())

print('\nAnxious Before Exams variations:')
print(df['Anxious Before Exams'].value_counts())

print('\nAcademic Performance Change variations:')
print(df['Academic Performance Change'].value_counts())
# Out:
# Xử lý giá trị không nhất quán trong định tính:
#
# Gender variations:
# Gender
# Male      470
# Female    470
# Other      50
# male        4
# Femal       3
# female      2
# Mal         1
# Name: count, dtype: int64
#
# Stress Level variations:
# Stress Level
# Medium       479
# Low          318
# High         180
# medium         8
# low            7
# MEDIUM         4
# Very High      2
# Neutral        1
# high           1
# Name: count, dtype: int64
#
# Anxious Before Exams variations:
# Anxious Before Exams
# Yes    506
# No     482
# YES      4
# yes      3
# NO       3
# no       2
# Name: count, dtype: int64
#
# Academic Performance Change variations:
# Academic Performance Change
# Same         395
# Improved     299
# Declined     296
# Improvedd      4
# same           4
# Declin         2
# Name: count, dtype: int64

# %%
#4. Giai đoạn tiếp theo sẽ là xử lý các vấn đề đã phát hiện trong quá trình kiểm tra dữ liệu: làm sạch dữ liệu, chuẩn hóa dữ liệu và xử lý các giá trị bất thường.
print("=" * 80)
print("GIAI ĐOẠN: DATA CLEANING VỚI PYTHON")
print("=" * 80)
#4.1 Xử lý missing data bằng median,mode hoặc mean:
print("\nBước 1: XỬ LÝ GIÁ TRỊ THIẾU")
from scipy import stats
# Tạo bản sao của dataframe gốc để làm sạch dữ liệu
df_cleaned = df.copy()
# Xử lý giá trị định lượng: dùng median hoặc mean
df_cleaned["Screen Time (hrs/day)"].fillna(df_cleaned["Screen Time (hrs/day)"].median(), inplace=True)
df_cleaned["Sleep Duration (hrs)"].fillna(df_cleaned["Sleep Duration (hrs)"].median(), inplace=True)
df_cleaned["Physical Activity (hrs/week)"].fillna(df_cleaned["Physical Activity (hrs/week)"].median(), inplace=True)
print('\nKiểm tra lại giá trị thiếu sau khi xử lý:')
print(df_cleaned.isnull().sum())
# xử lý dữ liệu trùng lặp:
df_cleaned.drop_duplicates(inplace=True)
print(f'Số lượng bản ghi sau khi loại bỏ trùng lặp: {len(df_cleaned)}')
# Out:
# ================================================================================
# GIAI ĐOẠN: DATA CLEANING VỚI PYTHON
# ================================================================================
#
# Bước 1: XỬ LÝ GIÁ TRỊ THIẾU
#
# Kiểm tra lại giá trị thiếu sau khi xử lý:
# Name                            0
# Gender                          0
# Age                             0
# Education Level                 0
# Screen Time (hrs/day)           0
# Sleep Duration (hrs)            0
# Physical Activity (hrs/week)    0
# Stress Level                    0
# Anxious Before Exams            0
# Academic Performance Change     0
# dtype: int64
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3108\1686478201.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned["Screen Time (hrs/day)"].fillna(df_cleaned["Screen Time (hrs/day)"].median(), inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3108\1686478201.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned["Sleep Duration (hrs)"].fillna(df_cleaned["Sleep Duration (hrs)"].median(), inplace=True)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3108\1686478201.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned["Physical Activity (hrs/week)"].fillna(df_cleaned["Physical Activity (hrs/week)"].median(), inplace=True)

# %%
print("\nBước 2: CHUẨN HÓA CATEGORICAL VALUES")
# 4.2 Chuẩn hóa dữ liệu định tính:
# 4.2.1 Chuẩn hóa Gender:
gender_mapping = {
    'Male':'Male','male':'Male','Mal':'Male',
    'Female':'Female','female':'Female','Femal':'Female',
    'Other':'Other'
}
df_cleaned['Gender'] = df_cleaned['Gender'].map(gender_mapping)
print('\nGender sau khi chuẩn hóa:')
print(df_cleaned['Gender'].unique())

# 4.2.2 Chuẩn hóa Stress Level:
stress_mapping = {
    'Low': 'Low', 'low': 'Low',
    'Medium': 'Medium', 'medium': 'Medium', 'MEDIUM': 'Medium',
    'High': 'High', 'high': 'High',
    'Very High': 'Very High',
    'Neutral': 'Medium'  # Neutral được gán thành Medium
}
df_cleaned['Stress Level'] = df_cleaned['Stress Level'].map(stress_mapping)
print('\nStress Level sau khi chuẩn hóa:')
print(df_cleaned['Stress Level'].unique())

# 4.2.3 Chuẩn hóa Anxious Before Exams:
#       Anxious Before Exams - standardize
anxious_mapping = {
    'Yes': 'Yes', 'YES': 'Yes', 'yes': 'Yes',
    'No': 'No', 'NO': 'No', 'no': 'No'
}
df_cleaned['Anxious Before Exams'] = df_cleaned['Anxious Before Exams'].map(anxious_mapping)
print(f"Anixious sau khi chuẩn hóa: {df_cleaned['Anxious Before Exams'].unique()}")

# 4.2.4 Chuẩn hóa Academic Performance Change:
#       Academic Performance Change
performance_mapping = {
    'Same': 'Same', 'same': 'Same',
    'Improved': 'Improved', 'Improvedd': 'Improved',
    'Declined': 'Declined', 'Declin': 'Declined'
}
df_cleaned['Academic Performance Change'] = df_cleaned['Academic Performance Change'].map(performance_mapping)
print(f"Academic Performance sau khi chuẩn hóa: {df_cleaned['Academic Performance Change'].unique()}")

# 4.2.5 Chuẩn hóa Education Level:
#       Education Level - loại bỏ khoảng trắng thừa
df_cleaned['Education Level'] = df_cleaned['Education Level'].str.strip()
print(f"Education Level sau khi chuẩn hóa: {df_cleaned['Education Level'].nunique()} unique values")
# Out:
# Bước 2: CHUẨN HÓA CATEGORICAL VALUES
#
# Gender sau khi chuẩn hóa:
# ['Male' 'Female' 'Other']
#
# Stress Level sau khi chuẩn hóa:
# ['Medium' 'High' 'Low' 'Very High']
# Anixious sau khi chuẩn hóa: ['No' 'Yes']
# Academic Performance sau khi chuẩn hóa: ['Same' 'Improved' 'Declined']
# Education Level sau khi chuẩn hóa: 11 unique values

# %%
#5. Xử lý giá trị bất thường (outliers):
print("\nBước 3: XỬ LÝ OUTLIERS")

#5.1 Xử lý outliers của Age:
# Age: Phạm vị tuổi hợp lý từ 15 đến 35:
outlier_age = len(df_cleaned[(df_cleaned['Age'] < 15) | (df_cleaned['Age'] > 35)])
df_cleaned['Age'] = df_cleaned['Age'].clip(lower=15, upper=35)
print(f'Số lượng outliers Age đã được xử lý: {outlier_age}')

#5.2 Xử lý outliers của Screen Time:
# Screen time: Thời gian ngồi màn hình hợp lý từ 0 đến 15 giờ/ngày:
outlier_screen_time = len(df_cleaned[df_cleaned['Screen Time (hrs/day)'] > 15])
df_cleaned['Screen Time (hrs/day)'] = df_cleaned['Screen Time (hrs/day)'].clip(upper=15)
print(f'Số lượng outliers Screen Time đã được xử lý: {outlier_screen_time}')

#5.3 Xử lý outliers của Sleep Duration:
# Sleep Duration: Thời gian ngủ hợp lý từ 3 đến 12 giờ/ngày:
outlier_Sleep = len(df_cleaned[(df_cleaned['Sleep Duration (hrs)'] < 3) | (df_cleaned['Sleep Duration (hrs)'] > 12)])
df_cleaned['Sleep Duration (hrs)'] = df_cleaned['Sleep Duration (hrs)'].clip(lower=3, upper=12)
print(f'Số lượng outliers Sleep Duration đã được xử lý: {outlier_Sleep}')

#5.4 Xử lý outliers của Physical Activity:
# Physical Activity: Thời gian hoạt động thể chất hợp lý từ 0 đến 50 giờ/tuần:
outlier_Physical_Activity = len(df_cleaned[df_cleaned['Physical Activity (hrs/week)'] > 50])
df_cleaned['Physical Activity (hrs/week)'] = df_cleaned['Physical Activity (hrs/week)'].clip(upper=50)
print(f'Số lượng outliers Physical Activity đã được xử lý: {outlier_Physical_Activity}')
# Out:
# Bước 3: XỬ LÝ OUTLIERS
# Số lượng outliers Age đã được xử lý: 4
# Số lượng outliers Screen Time đã được xử lý: 5
# Số lượng outliers Sleep Duration đã được xử lý: 5
# Số lượng outliers Physical Activity đã được xử lý: 3

# %%
print("\nDữ liệu sau khi làm sạch:")
print(f'Ghi chép dữ liệu gốc: {len(df)}')
print(f'Ghi chép dữ liệu sau khi làm sạch: {len(df_cleaned)}')
print(f'Ghi chép dữ liệu thừa:{len(df) - len(df_cleaned)}')
# Out:
# Dữ liệu sau khi làm sạch:
# Ghi chép dữ liệu gốc: 1000
# Ghi chép dữ liệu sau khi làm sạch: 1000
# Ghi chép dữ liệu thừa:0

# %%
print("\nThông tin dữ liệu sau khi làm sạch:")
print(df_cleaned.info())
# Out:
# Thông tin dữ liệu sau khi làm sạch:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          1000 non-null   object
#  1   Gender                        1000 non-null   object
#  2   Age                           1000 non-null   int64
#  3   Education Level               1000 non-null   object
#  4   Screen Time (hrs/day)         1000 non-null   float64
#  5   Sleep Duration (hrs)          1000 non-null   float64
#  6   Physical Activity (hrs/week)  1000 non-null   float64
#  7   Stress Level                  1000 non-null   object
#  8   Anxious Before Exams          1000 non-null   object
#  9   Academic Performance Change   1000 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 85.9+ KB
# None

# %%
print("\n5 dòng đầu tiên của dữ liệu sau khi làm sạch:")
print(df_cleaned.head())
# Out:
# 5 dòng đầu tiên của dữ liệu sau khi làm sạch:
#      Name  Gender  Age Education Level  Screen Time (hrs/day)  \
# 0   Aarav    Male   15         Class 8                    7.1
# 1   Meera  Female   25             MSc                    3.3
# 2  Ishaan    Male   20           BTech                    9.5
# 3  Aditya    Male   20              BA                   10.8
# 4   Anika  Female   17        Class 11                    2.8
#
#    Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# 0                   8.9                           9.3       Medium
# 1                   3.0                           0.2       Medium
# 2                   5.4                           6.2       Medium
# 3                   5.6                          50.0         High
# 4                   5.4                           3.1       Medium
#
#   Anxious Before Exams Academic Performance Change
# 0                   No                        Same
# 1                   No                        Same
# 2                   No                        Same
# 3                  Yes                        Same
# 4                  Yes                        Same

# %%
print("\nThống kê mô tả dữ liệu sau khi làm sạch:")
print(df_cleaned.describe())
# Out:
# Thống kê mô tả dữ liệu sau khi làm sạch:
#                Age  Screen Time (hrs/day)  Sleep Duration (hrs)  \
# count  1000.000000            1000.000000           1000.000000
# mean     20.364000               6.928600              6.477200
# std       3.520781               2.930152              1.491706
# min      15.000000               2.000000              3.000000
# 25%      17.000000               4.500000              5.200000
# 50%      20.000000               6.900000              6.500000
# 75%      23.000000               9.500000              7.700000
# max      35.000000              15.000000             12.000000
#
#        Physical Activity (hrs/week)
# count                   1000.000000
# mean                       5.214300
# std                        4.068294
# min                        0.000000
# 25%                        2.675000
# 50%                        5.100000
# 75%                        7.600000
# max                       50.000000

# %%
print("\n Đếm trong các cột Categori sau khi làm sạch:")
for col in ['Gender','Education Level','Stress Level','Anxious Before Exams','Academic Performance Change']:
    print(f'\nPhân phối cua cột {col}:')
    print(df_cleaned[col].value_counts())
# Out:
#  Đếm trong các cột Categori sau khi làm sạch:
#
# Phân phối cua cột Gender:
# Gender
# Male      475
# Female    475
# Other      50
# Name: count, dtype: int64
#
# Phân phối cua cột Education Level:
# Education Level
# MTech       143
# MSc         138
# MA          129
# Class 11     88
# Class 9      87
# Class 10     87
# BSc          85
# BTech        84
# BA           62
# Class 8      50
# Class 12     47
# Name: count, dtype: int64
#
# Phân phối cua cột Stress Level:
# Stress Level
# Medium       492
# Low          325
# High         181
# Very High      2
# Name: count, dtype: int64
#
# Phân phối cua cột Anxious Before Exams:
# Anxious Before Exams
# Yes    513
# No     487
# Name: count, dtype: int64
#
# Phân phối cua cột Academic Performance Change:
# Academic Performance Change
# Same        399
# Improved    303
# Declined    298
# Name: count, dtype: int64

# %%
# Tạo danh sách các biến định lượng vẽ biểu đồ phân phối sau khi làm sạch
df_cleaned.columns = df_cleaned.columns.str.strip() # Đản bảo cột chính xác
num_cols = ["Screen Time (hrs/day)", "Sleep Duration (hrs)","Physical Activity (hrs/week)"]
# Khởi tạo biểu đồ phân phối cho các biến định lượng
plt.figure(figsize=(18, 5))
# Vẽ biểu đồ phân phối cho từng biến định lượng
for i, col in enumerate(num_cols):
    plt.subplot(1,3, i + 1)
    sns.boxplot(x='Stress Level', y=col, data=df_cleaned)
    plt.title(f'Phân phối của {col} theo mức độ căng thẳng')
    plt.xlabel('Stress Level')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
# Bước 5: Xuất dữ liệu đã làm sạch ra file CSV mới
# Xuất dữ liệu đã làm sach ra file CSV:
df_cleaned.to_csv(r'D:\Do An Cuoi Ky\Student Mental Health Analysis\Student_Mental_Health_Analysis_Cleaned.csv', index=False)
print("\nDữ liệu đã làm sạch đã được xuất ra file CSV mới.")
# Out:
# Dữ liệu đã làm sạch đã được xuất ra file CSV mới.

# %%
# Xuất dữ liệu đã làm sach ra file JSON:
df_cleaned.to_json(r'D:\Do An Cuoi Ky\Student Mental Health Analysis\Student_Mental_Health_Analysis_Cleaned.json', orient='records', lines=True)
print("Dữ liệu đã làm sạch đã được xuất ra file JSON mới.")
# Out:
# Dữ liệu đã làm sạch đã được xuất ra file JSON mới.
